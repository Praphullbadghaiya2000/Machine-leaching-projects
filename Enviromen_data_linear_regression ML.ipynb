# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np
df=pd.read_csv("global_climate_co2_anomalies.csv")

# %%
df
# Out:
#          country iso_code  year  month      continent  income_group  latitude  \
# 0      Argentina      ARG  1990      1  South America  Upper Middle     -34.0
# 1      Argentina      ARG  1990      2  South America  Upper Middle     -34.0
# 2      Argentina      ARG  1990      3  South America  Upper Middle     -34.0
# 3      Argentina      ARG  1990      4  South America  Upper Middle     -34.0
# 4      Argentina      ARG  1990      5  South America  Upper Middle     -34.0
# ...          ...      ...   ...    ...            ...           ...       ...
# 12595    Vietnam      VNM  2024      8           Asia  Lower Middle      16.0
# 12596    Vietnam      VNM  2024      9           Asia  Lower Middle      16.0
# 12597    Vietnam      VNM  2024     10           Asia  Lower Middle      16.0
# 12598    Vietnam      VNM  2024     11           Asia  Lower Middle      16.0
# 12599    Vietnam      VNM  2024     12           Asia  Lower Middle      16.0
#
# ...

# %%
df.isnull().sum()
# Out:
# country                          0
# iso_code                         0
# year                             0
# month                            0
# continent                        0
# income_group                     0
# latitude                         0
# longitude                        0
# latitude_band                    0
# climate_zone                     0
# temp_anomaly_global              0
# temp_anomaly_land                0
# temp_anomaly_ocean               0
# temp_anomaly_arctic              0
# temp_max                         0
# temp_min                         0
# co2_emissions                    0
# co2_per_capita                   0
# co2_per_gdp                      0
# cumulative_co2                   0
# co2_concentration_ppm            0
# methane_emissions                0
# nitrous_oxide                    0
# total_ghg                        0
# land_use_change_co2              0
# sea_ice_extent_arctic         1179
# sea_ice_extent_antarc         1211
# ...

# %%
df.sample(10)
# Out:
#             country iso_code  year  month      continent  income_group  \
# 3085       Ethiopia      ETH  2002      2         Africa    Low Income
# 7053    New Zealand      NZL  2017     10        Oceania   High Income
# 9571   Saudi Arabia      SAU  2017      8           Asia   High Income
# 930      Bangladesh      BGD  1997      7           Asia  Lower Middle
# 6397         Mexico      MEX  1998      2  North America  Upper Middle
# 10759        Sweden      SWE  2011      8         Europe   High Income
# 10864        Sweden      SWE  2020      5         Europe   High Income
# 12309       Vietnam      VNM  2000     10           Asia  Lower Middle
# 7         Argentina      ARG  1990      8  South America  Upper Middle
# 867      Bangladesh      BGD  1992      4           Asia  Lower Middle
#
#        latitude  longitude latitude_band climate_zone  ...  forest_cover_pct  \
# 3085        9.0       40.0      Tropical     Tropical  ...                15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12600 entries, 0 to 12599
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   country                     12600 non-null  object
#  1   iso_code                    12600 non-null  object
#  2   year                        12600 non-null  int64
#  3   month                       12600 non-null  int64
#  4   continent                   12600 non-null  object
#  5   income_group                12600 non-null  object
#  6   latitude                    12600 non-null  float64
#  7   longitude                   12600 non-null  float64
#  8   latitude_band               12600 non-null  object
#  9   climate_zone                12600 non-null  object
#  10  temp_anomaly_global         12600 non-null  float64
#  11  temp_anomaly_land           12600 non-null  float64
#  12  temp_anomaly_ocean          12600 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# country                          0
# iso_code                         0
# year                             0
# month                            0
# continent                        0
# income_group                     0
# latitude                         0
# longitude                        0
# latitude_band                    0
# climate_zone                     0
# temp_anomaly_global              0
# temp_anomaly_land                0
# temp_anomaly_ocean               0
# temp_anomaly_arctic              0
# temp_max                         0
# temp_min                         0
# co2_emissions                    0
# co2_per_capita                   0
# co2_per_gdp                      0
# cumulative_co2                   0
# co2_concentration_ppm            0
# methane_emissions                0
# nitrous_oxide                    0
# total_ghg                        0
# land_use_change_co2              0
# sea_ice_extent_arctic         1179
# sea_ice_extent_antarc         1211
# ...

# %%
df.sample(2)
# Out:
#         country iso_code  year  month continent  income_group  latitude  \
# 8564     Poland      POL  2003      9    Europe   High Income      52.0
# 4754  Indonesia      IDN  2001      3      Asia  Lower Middle      -5.0
#
#       longitude latitude_band climate_zone  ...  forest_cover_pct  \
# 8564       20.0     Temperate  Continental  ...                30
# 4754      120.0      Tropical     Tropical  ...                54
#
#       industrial_share_gdp  agriculture_share_gdp  vehicle_ownership  \
# 8564                    33                      4              378.0
# 4754                    42                     16               86.0
#
#       radiative_forcing  temp_change_from_co2  climate_risk_score  \
# 8564              2.767                  0.45                27.0
# 4754              2.649                  0.39                20.0
#
#       warming_category  renewable_transition_stage  emission_intensity_level
# ...

# %%
df["country"].unique()
# Out:
# array(['Argentina', 'Australia', 'Bangladesh', 'Brazil', 'Canada',
#        'China', 'Egypt', 'Ethiopia', 'France', 'Germany', 'India',
#        'Indonesia', 'Iran', 'Japan', 'Kenya', 'Mexico', 'New Zealand',
#        'Nigeria', 'Norway', 'Pakistan', 'Poland', 'Russia',
#        'Saudi Arabia', 'South Africa', 'South Korea', 'Sweden', 'Turkey',
#        'United Kingdom', 'United States', 'Vietnam'], dtype=object)

# %%
#ok

# %%
df["iso_code"].unique()
# Out:
# array(['ARG', 'AUS', 'BGD', 'BRA', 'CAN', 'CHN', 'EGY', 'ETH', 'FRA',
#        'DEU', 'IND', 'IDN', 'IRN', 'JPN', 'KEN', 'MEX', 'NZL', 'NGA',
#        'NOR', 'PAK', 'POL', 'RUS', 'SAU', 'ZAF', 'KOR', 'SWE', 'TUR',
#        'GBR', 'USA', 'VNM'], dtype=object)

# %%
df["iso_code"].nunique()
# Out:
# 30

# %%
df["year"].nunique()
# Out:
# 35

# %%
df["year"].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024])

# %%
df["continent"].unique()
# Out:
# array(['South America', 'Oceania', 'Asia', 'North America', 'Africa',
#        'Europe'], dtype=object)

# %%
df["continent"].nunique()
# Out:
# 6

# %%
df["income_group"].unique()
# Out:
# array(['Upper Middle', 'High Income', 'Lower Middle', 'Low Income'],
#       dtype=object)

# %%
df["income_group"].nunique()
# Out:
# 4

# %%
df["latitude"].unique()
# Out:
# array([-34., -27.,  24., -15.,  56.,  35.,  27.,   9.,  46.,  51.,  20.,
#         -5.,  32.,  36.,  -1.,  23., -42.,  60.,  30.,  52.,  61., -29.,
#         37.,  62.,  39.,  54.,  38.,  16.])

# %%
df["latitude"].nunique()
# Out:
# 28

# %%
df["longitude"].unique()
# Out:
# array([ -64.,  133.,   90.,  -53.,  -96.,  105.,   30.,   40.,    2.,
#          10.,   77.,  120.,   53.,  138.,   38., -102.,  172.,    8.,
#          69.,   20.,   45.,   25.,  128.,   15.,   35.,   -2.,  -97.,
#         107.])

# %%
df["longitude"].nunique()
# Out:
# 28

# %%
df["latitude_band"].unique()
# Out:
# array(['Temperate', 'Subtropical', 'Tropical', 'Polar'], dtype=object)

# %%
df["latitude_band"].nunique()
# Out:
# 4

# %%
df["climate_zone"].unique()
# Out:
# array(['Temperate', 'Dry', 'Tropical', 'Continental'], dtype=object)

# %%
df["climate_zone"].unique()
# Out:
# array(['Temperate', 'Dry', 'Tropical', 'Continental'], dtype=object)

# %%
for column in df.columns:
    print(f"\ncolumn:{column}")
    print(f"unique values:{df[column].unique()}")
    print(f"value counts:\n{df[column].value_counts()}")
# Out:
# column:country
# unique values:['Argentina' 'Australia' 'Bangladesh' 'Brazil' 'Canada' 'China' 'Egypt'
#  'Ethiopia' 'France' 'Germany' 'India' 'Indonesia' 'Iran' 'Japan' 'Kenya'
#  'Mexico' 'New Zealand' 'Nigeria' 'Norway' 'Pakistan' 'Poland' 'Russia'
#  'Saudi Arabia' 'South Africa' 'South Korea' 'Sweden' 'Turkey'
#  'United Kingdom' 'United States' 'Vietnam']
# value counts:
# country
# Argentina         420
# Australia         420
# Bangladesh        420
# Brazil            420
# Canada            420
# China             420
# Egypt             420
# Ethiopia          420
# France            420
# Germany           420
# India             420
# Indonesia         420
# Iran              420
# Japan             420
# Kenya             420
# Mexico            420
# New Zealand       420
# Nigeria           420
# Norway            420
# Pakistan          420
# Poland            420
# Russia            420
# Saudi Arabia      420
# South Africa      420
# South Korea       420
# ...

# %%
df.dtypes
# Out:
# country                        object
# iso_code                       object
# year                            int64
# month                           int64
# continent                      object
# income_group                   object
# latitude                      float64
# longitude                     float64
# latitude_band                  object
# climate_zone                   object
# temp_anomaly_global           float64
# temp_anomaly_land             float64
# temp_anomaly_ocean            float64
# temp_anomaly_arctic           float64
# temp_max                      float64
# temp_min                      float64
# co2_emissions                 float64
# co2_per_capita                float64
# co2_per_gdp                   float64
# cumulative_co2                float64
# co2_concentration_ppm           int64
# methane_emissions             float64
# nitrous_oxide                 float64
# total_ghg                     float64
# land_use_change_co2           float64
# ...

# %%
df.isnull().sum()
# Out:
# country                          0
# iso_code                         0
# year                             0
# month                            0
# continent                        0
# income_group                     0
# latitude                         0
# longitude                        0
# latitude_band                    0
# climate_zone                     0
# temp_anomaly_global              0
# temp_anomaly_land                0
# temp_anomaly_ocean               0
# temp_anomaly_arctic              0
# temp_max                         0
# temp_min                         0
# co2_emissions                    0
# co2_per_capita                   0
# co2_per_gdp                      0
# cumulative_co2                   0
# co2_concentration_ppm            0
# methane_emissions                0
# nitrous_oxide                    0
# total_ghg                        0
# land_use_change_co2              0
# sea_ice_extent_arctic         1179
# sea_ice_extent_antarc         1211
# ...

# %%
sns.histplot(data=df , x="sea_ice_extent_arctic")
# Out:
# <Axes: xlabel='sea_ice_extent_arctic', ylabel='Count'>

# %%
df["sea_ice_extent_arctic"]=df["sea_ice_extent_arctic"].fillna(df["sea_ice_extent_arctic"].mean())

# %%
df["sea_ice_extent_arctic"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# country                          0
# iso_code                         0
# year                             0
# month                            0
# continent                        0
# income_group                     0
# latitude                         0
# longitude                        0
# latitude_band                    0
# climate_zone                     0
# temp_anomaly_global              0
# temp_anomaly_land                0
# temp_anomaly_ocean               0
# temp_anomaly_arctic              0
# temp_max                         0
# temp_min                         0
# co2_emissions                    0
# co2_per_capita                   0
# co2_per_gdp                      0
# cumulative_co2                   0
# co2_concentration_ppm            0
# methane_emissions                0
# nitrous_oxide                    0
# total_ghg                        0
# land_use_change_co2              0
# sea_ice_extent_arctic            0
# sea_ice_extent_antarc         1211
# ...

# %%
df["sea_ice_extent_antarc"]=df["sea_ice_extent_antarc"].fillna(df["sea_ice_extent_antarc"].mean())

# %%
df["sea_ice_extent_antarc"].isnull().sum()
# Out:
# 0

# %%
df["ocean_heat_content"]=df["ocean_heat_content"].fillna(df["ocean_heat_content"].mean())

# %%
df["ocean_heat_content"].isnull().sum()
# Out:
# 0

# %%
df["renewable_capacity_gw"]=df["renewable_capacity_gw"].fillna(df["renewable_capacity_gw"].mean())

# %%
df["renewable_capacity_gw"].isnull().sum()
# Out:
# 0

# %%
df["vehicle_ownership"]=df["vehicle_ownership"].fillna(df["vehicle_ownership"].mean())

# %%
df["vehicle_ownership"].isnull().sum()
# Out:
# 0

# %%
df["sea_surface_temp_anom"]=df["sea_surface_temp_anom"].fillna(df["sea_surface_temp_anom"].mean())

# %%
## here we have replace all numerical columns missing values with there mean , now our data do not have any missing value
df.isnull().sum()
# Out:
# country                       0
# iso_code                      0
# year                          0
# month                         0
# continent                     0
# income_group                  0
# latitude                      0
# longitude                     0
# latitude_band                 0
# climate_zone                  0
# temp_anomaly_global           0
# temp_anomaly_land             0
# temp_anomaly_ocean            0
# temp_anomaly_arctic           0
# temp_max                      0
# temp_min                      0
# co2_emissions                 0
# co2_per_capita                0
# co2_per_gdp                   0
# cumulative_co2                0
# co2_concentration_ppm         0
# methane_emissions             0
# nitrous_oxide                 0
# total_ghg                     0
# land_use_change_co2           0
# sea_ice_extent_arctic         0
# sea_ice_extent_antarc         0
# sea_surface_temp_anom         0
# nino34_index                  0
# ...

# %%
df.describe()
# Out:
#                year        month      latitude     longitude  \
# count  12600.000000  12600.00000  12600.000000  12600.000000
# mean    2007.000000      6.50000     22.933333     38.633333
# std       10.099906      3.45219     29.217517     71.192002
# min     1990.000000      1.00000    -42.000000   -102.000000
# 25%     1998.000000      3.75000      9.000000      8.000000
# 50%     2007.000000      6.50000     28.500000     36.500000
# 75%     2016.000000      9.25000     46.000000    105.000000
# max     2024.000000     12.00000     62.000000    172.000000
#
#        temp_anomaly_global  temp_anomaly_land  temp_anomaly_ocean  \
# count         12600.000000       12600.000000        12600.000000
# mean              0.701583           1.081641            0.561374
# std               0.321898           0.324362            0.323463
# min               0.090000           0.490000           -0.070000
# 25%               0.440000           0.830000            0.310000
# ...

# %%
df.shape
# Out:
# (12600, 54)

# %%
df_num=df.select_dtypes(include=['number'])
df_num
# Out:
#        year  month  latitude  longitude  temp_anomaly_global  \
# 0      1990      1     -34.0      -64.0                 0.40
# 1      1990      2     -34.0      -64.0                 0.43
# 2      1990      3     -34.0      -64.0                 0.36
# 3      1990      4     -34.0      -64.0                 0.49
# 4      1990      5     -34.0      -64.0                 0.39
# ...     ...    ...       ...        ...                  ...
# 12595  2024      8      16.0      107.0                 1.61
# 12596  2024      9      16.0      107.0                 1.60
# 12597  2024     10      16.0      107.0                 1.68
# 12598  2024     11      16.0      107.0                 1.58
# 12599  2024     12      16.0      107.0                 1.61
#
#        temp_anomaly_land  temp_anomaly_ocean  temp_anomaly_arctic  temp_max  \
# 0                   0.88                0.28                 0.82      -7.0
# 1                   0.81                0.28                 0.91      -5.2
# ...

# %%
x=df_num.iloc[:,0:44]
x
# Out:
#        year  month  latitude  longitude  temp_anomaly_global  \
# 0      1990      1     -34.0      -64.0                 0.40
# 1      1990      2     -34.0      -64.0                 0.43
# 2      1990      3     -34.0      -64.0                 0.36
# 3      1990      4     -34.0      -64.0                 0.49
# 4      1990      5     -34.0      -64.0                 0.39
# ...     ...    ...       ...        ...                  ...
# 12595  2024      8      16.0      107.0                 1.61
# 12596  2024      9      16.0      107.0                 1.60
# 12597  2024     10      16.0      107.0                 1.68
# 12598  2024     11      16.0      107.0                 1.58
# 12599  2024     12      16.0      107.0                 1.61
#
#        temp_anomaly_land  temp_anomaly_ocean  temp_anomaly_arctic  temp_max  \
# 0                   0.88                0.28                 0.82      -7.0
# 1                   0.81                0.28                 0.91      -5.2
# ...

# %%
y=df_num.iloc[:,-1]
y
# Out:
# 0        12.2
# 1        18.5
# 2        19.6
# 3        15.1
# 4        13.0
#          ...
# 12595    72.1
# 12596    77.4
# 12597    65.1
# 12598    54.8
# 12599    56.2
# Name: climate_risk_score, Length: 12600, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train , x_test, y_train ,y_test= train_test_split(x,y, test_size=0.2)

# %%
x_train.shape
# Out:
# (10080, 44)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_train_scaled 
x_test_scaled=scaler.transform(x_test)
x_test_scaled
# Out:
# array([[-0.89340038,  0.43507924, -1.7845454 , ..., -0.5821262 ,
#         -0.89340038, -0.22471454],
#        [ 1.3791627 , -1.29995917, -0.10177953, ..., -1.0457094 ,
#          1.3791627 ,  1.07741265],
#        [-0.89340038,  1.59177152,  1.27190689, ...,  0.74908059,
#         -0.89340038, -0.22471454],
#        ...,
#        [-1.28862874,  0.14590617, -0.4795433 , ..., -1.27962753,
#         -1.28862874, -1.28570708],
#        [-0.20175075,  0.43507924,  0.03558911, ...,  1.14461488,
#         -0.20175075,  0.01642012],
#        [ 0.39109179, -1.29995917, -0.4795433 , ..., -1.0754808 ,
#          0.39109179, -0.22471454]])

# %%
from sklearn.linear_model  import LinearRegression 
clf=LinearRegression()
clf.fit( x_train_scaled,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sklearn.linear_model  import LinearRegression
#       2 clf=LinearRegression()
# ----> 3 clf.fit( x_train_scaled,y_train)
#
# NameError: name 'x_train_scaled' is not defined

# %%
y_pred=clf.predict(x_test_scaled)
[y_pred]

# %%
y_test
